# %%
import numpy as np
import matplotlib.pyplot as plt
states = np.load('states.npy')

# %%
posex = states[:,3]
posey = states[:,5]
posez = states[:,7]
omegax = states[:,9]
omegay = states[:,10]
omegaz = states[:,11]
# Out:
# (10000,)

# %%
time = 10000
t = range(time)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(posex, posey, posez)
